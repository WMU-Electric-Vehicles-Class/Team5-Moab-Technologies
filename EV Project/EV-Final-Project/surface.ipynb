# %%
import numpy as np
import pandas as pd
from scipy.interpolate import LinearNDInterpolator
from matplotlib import pyplot as plt

# %% [markdown]
# Front motor data

# %%
front = pd.read_excel("data/Audi_e_Tron_Motors_ResultsForMaps.xlsx", "APA250-Maps")
front
# Out:
#     SPEED [rad/s]  TORQUE [Nm]   EFFY [%]  JLossTot [W]  Unnamed: 4      SLIP  \
# 0       13.217688    21.938861   3.623169   7705.256861         NaN  9.816327
# 1       18.689936     3.570540  64.226239     34.434394         NaN  6.142857
# 2       23.650243    48.618619   4.427373  24803.651854         NaN  9.632653
# 3       24.140825    14.169394  51.699565    309.962348         NaN  5.959184
# 4       41.550011     6.130481  70.645493     93.364720         NaN  2.102041
# ..            ...          ...        ...           ...         ...       ...
# 93    1464.520017    26.698920  97.422274    768.797547         NaN  1.000000
# 94    1479.200051    16.239395  97.398176    471.905172         NaN  1.000000
# 95    1499.602811     9.132883  97.363883    269.034125         NaN  1.000000
# 96    1514.282845     3.657322  97.284527    109.056572         NaN  1.000000
# 97    1549.365638    38.949840  97.454238   1184.849909         NaN  1.000000
#
# ...

# %%
x1 = front["SPEED [rad/s]"]
y1 = front["TORQUE [Nm]"]
z1 = front["EFFY [%]"]

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=90, azim=-90)

surf = ax.plot_trisurf(x1, y1, z1, cmap="coolwarm", linewidth=0)

# %% [markdown]
# Rear motor data

# %%
rear = pd.read_excel("data/Audi_e_Tron_Motors_ResultsForMaps.xlsx", "AKA320-Maps")
rear
# Out:
#      SPEED [rad/s]  TORQUE [Nm]   EFFY [%]  JLossTot [W]  Unnamed: 4  \
# 0        13.521704    23.229490  32.293396    649.683065         NaN
# 1        24.179135    44.859446  49.997574   1067.544963         NaN
# 2        24.533683    19.376930  60.345042    298.922990         NaN
# 3        24.967734     7.121327  79.384605     43.568193         NaN
# 4        32.733924    25.895505  80.901423    191.660389         NaN
# ..             ...          ...        ...           ...         ...
# 129    1562.060089    13.233551  98.105371    144.713830         NaN
# 130    1562.060089     0.976005  97.522878     13.020994         NaN
# 131    1563.252946     5.986375  95.708080     28.414180         NaN
# 132    1563.252946     0.449953  94.596081      2.686009         NaN
# 133    1563.642909     3.243890  96.905324     18.738580         NaN
#
#           SLIP  FREQUENCY [Hz]        SA [W]       V [V]       I [A]  \
# ...

# %%
x2 = rear["SPEED [rad/s]"]
y2 = rear["TORQUE [Nm]"]
z2 = rear["EFFY [%]"]

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=90, azim=-90)

surf = ax.plot_trisurf(x2, y2, z2, cmap="coolwarm", linewidth=0)

# %% [markdown]
# Front interpolation

# %%
interp_front = LinearNDInterpolator((x1, y1), z1)

xnew = np.linspace(min(x1), max(x1), 500)
ynew = np.linspace(min(y1), max(y1), 500)
xnew, ynew = np.meshgrid(xnew, ynew)
znew = interp_front(xnew, ynew)

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=90, azim=-90)
surf = ax.plot_surface(xnew, ynew, znew, cmap="coolwarm",
                       linewidth=0, antialiased=False)

# %% [markdown]
# Interpolate single point

# %%
x_test = 1000
y_test = 100
z_test = interp_front(x_test, y_test)
float(z_test)
# Out:
# 96.29318476855511

# %% [markdown]
# Rear interpolation

# %%
interp_rear = LinearNDInterpolator((x2, y2), z2)

xnew = np.linspace(min(x2), max(x2), 500)
ynew = np.linspace(min(y2), max(y2), 500)
xnew, ynew = np.meshgrid(xnew, ynew)
znew = interp_rear(xnew, ynew)

fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(elev=90, azim=-90)
surf = ax.plot_surface(xnew, ynew, znew, cmap="coolwarm",
                       linewidth=0, antialiased=False)

# %% [markdown]
# Interpolate single point

# %%
x_test = 1000
y_test = 100
z_test = interp_rear(x_test, y_test)
float(z_test)
# Out:
# 97.13605076914314

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=04b84d8e-8cea-4bd7-b863-0c6c0738da54' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
